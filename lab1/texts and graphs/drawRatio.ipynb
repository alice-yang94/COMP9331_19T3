# %%
import matplotlib.pyplot as plt

# %%
plt.plot([775, 6276, 16104], [6.67, 16.33, 5.29])
#plt.axis([775, 16104, 0, 18])
plt.xlabel('Physical distance in Km')
plt.ylabel('Ratio between RTT and T')
# Out:
# Text(0, 0.5, 'Ratio between RTT and T')
